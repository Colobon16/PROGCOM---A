# %% [markdown]
# <a href="https://colab.research.google.com/github/Colobon16/PROGCOM---A/blob/main/CQ8(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
      # Ejercicio 1 - SyntaxError: Missing colon (Ejercicio 1)

        **Descripción del error:** Falta ':' al final de la cabecera if/for/def.

        **Código con error**
        ```python
        x = 5
if x > 3
    print('mayor')
        ```

        **Por qué ocurre:** Falta ':' al final de la cabecera if/for/def.

        **Código corregido**
        ```python
        x = 5
if x > 3:
    print('mayor')
        ```

        ---


        # Ejercicio 2 - IndentationError: unexpected indent (Ejercicio 2)

        **Descripción del error:** El cuerpo de la función no está indentado.

        **Código con error**
        ```python
        def f():
print('hola')
        ```

        **Por qué ocurre:** El cuerpo de la función no está indentado.

        **Código corregido**
        ```python
        def f():
    print('hola')
        ```

        ---


        # Ejercicio 3 - NameError: name not defined (Ejercicio 3)

        **Descripción del error:** Se usa una variable no definida.

        **Código con error**
        ```python
        print(resultado)
        ```

        **Por qué ocurre:** Se usa una variable no definida.

        **Código corregido**
        ```python
        resultado = 10
print(resultado)
        ```

        ---


        # Ejercicio 4 - TypeError: unsupported operand type(s) (Ejercicio 4)

        **Descripción del error:** No se pueden sumar str y int sin conversión.

        **Código con error**
        ```python
        a = '5'
b = 3
print(a + b)
        ```

        **Por qué ocurre:** No se pueden sumar str y int sin conversión.

        **Código corregido**
        ```python
        a = '5'
b = 3
print(int(a) + b)
        ```

        ---


        # Ejercicio 5 - IndexError: list index out of range (Ejercicio 5)

        **Descripción del error:** Acceso a índice fuera de rango.

        **Código con error**
        ```python
        lst = [1,2,3]
print(lst[3])
        ```

        **Por qué ocurre:** Acceso a índice fuera de rango.

        **Código corregido**
        ```python
        lst = [1,2,3]
print(lst[2])
        ```

        ---


        # Ejercicio 6 - KeyError: key not found (Ejercicio 6)

        **Descripción del error:** Clave inexistente en diccionario.

        **Código con error**
        ```python
        d = {'a':1}
print(d['b'])
        ```

        **Por qué ocurre:** Clave inexistente en diccionario.

        **Código corregido**
        ```python
        d = {'a':1}
print(d.get('b', 'no existe'))
        ```

        ---


        # Ejercicio 7 - ValueError: invalid literal for int() (Ejercicio 7)

        **Descripción del error:** No se puede convertir 'dos' a entero.

        **Código con error**
        ```python
        x = 'dos'
n = int(x)
        ```

        **Por qué ocurre:** No se puede convertir 'dos' a entero.

        **Código corregido**
        ```python
        x = '2'
n = int(x)
        ```

        ---


        # Ejercicio 8 - ZeroDivisionError: division by zero (Ejercicio 8)

        **Descripción del error:** División por cero.

        **Código con error**
        ```python
        a = 10
b = 0
print(a/b)
        ```

        **Por qué ocurre:** División por cero.

        **Código corregido**
        ```python
        a = 10
b = 0
if b!=0:
    print(a/b)
else:
    print('división inválida')
        ```

        ---


        # Ejercicio 9 - AttributeError: object has no attribute (Ejercicio 9)

        **Descripción del error:** Tipo incorrecto para método append.

        **Código con error**
        ```python
        n = 5
n.append(3)
        ```

        **Por qué ocurre:** Tipo incorrecto para método append.

        **Código corregido**
        ```python
        lst = [5]
lst.append(3)
        ```

        ---


# Ejercicio 10 - ImportError / ModuleNotFoundError (Ejercicio 10)

**Descripción del error:** Nombre de módulo incorrecto o no instalado.

**Código con error**
```python
import numppy
```

**Por qué ocurre:** Nombre de módulo incorrecto o no instalado.

**Código corregido**
```python
import numpy as np
```

---


        # Ejercicio 11 - SyntaxError: Missing colon (Ejercicio 11)

        **Descripción del error:** Falta ':' al final de la cabecera if/for/def.

        **Código con error**
        ```python
        x = 5
if x > 3
    print('mayor')
        ```

        **Por qué ocurre:** Falta ':' al final de la cabecera if/for/def.

        **Código corregido**
        ```python
        x = 5
if x > 3:
    print('mayor')
        ```

        ---


        # Ejercicio 12 - IndentationError: unexpected indent (Ejercicio 12)

        **Descripción del error:** El cuerpo de la función no está indentado.

        **Código con error**
        ```python
        def f():
print('hola')
        ```

        **Por qué ocurre:** El cuerpo de la función no está indentado.

        **Código corregido**
        ```python
        def f():
    print('hola')
        ```

        ---


        # Ejercicio 13 - NameError: name not defined (Ejercicio 13)

        **Descripción del error:** Se usa una variable no definida.

        **Código con error**
        ```python
        print(resultado)
        ```

        **Por qué ocurre:** Se usa una variable no definida.

        **Código corregido**
        ```python
        resultado = 10
print(resultado)
        ```

        ---


        # Ejercicio 14 - TypeError: unsupported operand type(s) (Ejercicio 14)

        **Descripción del error:** No se pueden sumar str y int sin conversión.

        **Código con error**
        ```python
        a = '5'
b = 3
print(a + b)
        ```

        **Por qué ocurre:** No se pueden sumar str y int sin conversión.

        **Código corregido**
        ```python
        a = '5'
b = 3
print(int(a) + b)
        ```

        ---


        # Ejercicio 15 - IndexError: list index out of range (Ejercicio 15)

        **Descripción del error:** Acceso a índice fuera de rango.

        **Código con error**
        ```python
        lst = [1,2,3]
print(lst[3])
        ```

        **Por qué ocurre:** Acceso a índice fuera de rango.

        **Código corregido**
        ```python
        lst = [1,2,3]
print(lst[2])
        ```

        ---


        # Ejercicio 16 - KeyError: key not found (Ejercicio 16)

        **Descripción del error:** Clave inexistente en diccionario.

        **Código con error**
        ```python
        d = {'a':1}
print(d['b'])
        ```

        **Por qué ocurre:** Clave inexistente en diccionario.

        **Código corregido**
        ```python
        d = {'a':1}
print(d.get('b', 'no existe'))
        ```

        ---


        # Ejercicio 17 - ValueError: invalid literal for int() (Ejercicio 17)

        **Descripción del error:** No se puede convertir 'dos' a entero.

        **Código con error**
        ```python
        x = 'dos'
n = int(x)
        ```

        **Por qué ocurre:** No se puede convertir 'dos' a entero.

        **Código corregido**
        ```python
        x = '2'
n = int(x)
        ```

        ---


        # Ejercicio 18 - ZeroDivisionError: division by zero (Ejercicio 18)

        **Descripción del error:** División por cero.

        **Código con error**
        ```python
        a = 10
b = 0
print(a/b)
        ```

        **Por qué ocurre:** División por cero.

        **Código corregido**
        ```python
        a = 10
b = 0
if b!=0:
    print(a/b)
else:
    print('división inválida')
        ```

        ---


        # Ejercicio 19 - AttributeError: object has no attribute (Ejercicio 19)

        **Descripción del error:** Tipo incorrecto para método append.

        **Código con error**
        ```python
        n = 5
n.append(3)
        ```

        **Por qué ocurre:** Tipo incorrecto para método append.

        **Código corregido**
        ```python
        lst = [5]
lst.append(3)
        ```

        ---


# Ejercicio 20 - ImportError / ModuleNotFoundError (Ejercicio 20)

**Descripción del error:** Nombre de módulo incorrecto o no instalado.

**Código con error**
```python
import numppy
```

**Por qué ocurre:** Nombre de módulo incorrecto o no instalado.

**Código corregido**
```python
import numpy as np
```

---


        # Ejercicio 21 - SyntaxError: Missing colon (Ejercicio 21)

        **Descripción del error:** Falta ':' al final de la cabecera if/for/def.

        **Código con error**
        ```python
        x = 5
if x > 3
    print('mayor')
        ```

        **Por qué ocurre:** Falta ':' al final de la cabecera if/for/def.

        **Código corregido**
        ```python
        x = 5
if x > 3:
    print('mayor')
        ```

        ---


        # Ejercicio 022 - IndentationError: unexpected indent (Ejercicio 22)

        **Descripción del error:** El cuerpo de la función no está indentado.

        **Código con error**
        ```python
        def f():
print('hola')
        ```

        **Por qué ocurre:** El cuerpo de la función no está indentado.

        **Código corregido**
        ```python
        def f():
    print('hola')
        ```

        ---


        # Ejercicio 023 - NameError: name not defined (Ejercicio 23)

        **Descripción del error:** Se usa una variable no definida.

        **Código con error**
        ```python
        print(resultado)
        ```

        **Por qué ocurre:** Se usa una variable no definida.

        **Código corregido**
        ```python
        resultado = 10
print(resultado)
        ```

        ---


        # Ejercicio 024 - TypeError: unsupported operand type(s) (Ejercicio 24)

        **Descripción del error:** No se pueden sumar str y int sin conversión.

        **Código con error**
        ```python
        a = '5'
b = 3
print(a + b)
        ```

        **Por qué ocurre:** No se pueden sumar str y int sin conversión.

        **Código corregido**
        ```python
        a = '5'
b = 3
print(int(a) + b)
        ```

        ---


        # Ejercicio 025 - IndexError: list index out of range (Ejercicio 25)

        **Descripción del error:** Acceso a índice fuera de rango.

        **Código con error**
        ```python
        lst = [1,2,3]
print(lst[3])
        ```

        **Por qué ocurre:** Acceso a índice fuera de rango.

        **Código corregido**
        ```python
        lst = [1,2,3]
print(lst[2])
        ```

        ---


        # Ejercicio 026 - KeyError: key not found (Ejercicio 26)

        **Descripción del error:** Clave inexistente en diccionario.

        **Código con error**
        ```python
        d = {'a':1}
print(d['b'])
        ```

        **Por qué ocurre:** Clave inexistente en diccionario.

        **Código corregido**
        ```python
        d = {'a':1}
print(d.get('b', 'no existe'))
        ```

        ---


        # Ejercicio 027 - ValueError: invalid literal for int() (Ejercicio 27)

        **Descripción del error:** No se puede convertir 'dos' a entero.

        **Código con error**
        ```python
        x = 'dos'
n = int(x)
        ```

        **Por qué ocurre:** No se puede convertir 'dos' a entero.

        **Código corregido**
        ```python
        x = '2'
n = int(x)
        ```

        ---


        # Ejercicio 028 - ZeroDivisionError: division by zero (Ejercicio 28)

        **Descripción del error:** División por cero.

        **Código con error**
        ```python
        a = 10
b = 0
print(a/b)
        ```

        **Por qué ocurre:** División por cero.

        **Código corregido**
        ```python
        a = 10
b = 0
if b!=0:
    print(a/b)
else:
    print('división inválida')
        ```

        ---


        # Ejercicio 029 - AttributeError: object has no attribute (Ejercicio 29)

        **Descripción del error:** Tipo incorrecto para método append.

        **Código con error**
        ```python
        n = 5
n.append(3)
        ```

        **Por qué ocurre:** Tipo incorrecto para método append.

        **Código corregido**
        ```python
        lst = [5]
lst.append(3)
        ```

        ---


# Ejercicio 030 - ImportError / ModuleNotFoundError (Ejercicio 30)

**Descripción del error:** Nombre de módulo incorrecto o no instalado.

**Código con error**
```python
import numppy
```

**Por qué ocurre:** Nombre de módulo incorrecto o no instalado.

**Código corregido**
```python
import numpy as np
```

---


        # Ejercicio 031 - SyntaxError: Missing colon (Ejercicio 31)

        **Descripción del error:** Falta ':' al final de la cabecera if/for/def.

        **Código con error**
        ```python
        x = 5
if x > 3
    print('mayor')
        ```

        **Por qué ocurre:** Falta ':' al final de la cabecera if/for/def.

        **Código corregido**
        ```python
        x = 5
if x > 3:
    print('mayor')
        ```

        ---


        # Ejercicio 032 - IndentationError: unexpected indent (Ejercicio 32)

        **Descripción del error:** El cuerpo de la función no está indentado.

        **Código con error**
        ```python
        def f():
print('hola')
        ```

        **Por qué ocurre:** El cuerpo de la función no está indentado.

        **Código corregido**
        ```python
        def f():
    print('hola')
        ```

        ---


        # Ejercicio 033 - NameError: name not defined (Ejercicio 33)

        **Descripción del error:** Se usa una variable no definida.

        **Código con error**
        ```python
        print(resultado)
        ```

        **Por qué ocurre:** Se usa una variable no definida.

        **Código corregido**
        ```python
        resultado = 10
print(resultado)
        ```

        ---


        # Ejercicio 034 - TypeError: unsupported operand type(s) (Ejercicio 34)

        **Descripción del error:** No se pueden sumar str y int sin conversión.

        **Código con error**
        ```python
        a = '5'
b = 3
print(a + b)
        ```

        **Por qué ocurre:** No se pueden sumar str y int sin conversión.

        **Código corregido**
        ```python
        a = '5'
b = 3
print(int(a) + b)
        ```

        ---


        # Ejercicio 035 - IndexError: list index out of range (Ejercicio 35)

        **Descripción del error:** Acceso a índice fuera de rango.

        **Código con error**
        ```python
        lst = [1,2,3]
print(lst[3])
        ```

        **Por qué ocurre:** Acceso a índice fuera de rango.

        **Código corregido**
        ```python
        lst = [1,2,3]
print(lst[2])
        ```

        ---


        # Ejercicio 036 - KeyError: key not found (Ejercicio 36)

        **Descripción del error:** Clave inexistente en diccionario.

        **Código con error**
        ```python
        d = {'a':1}
print(d['b'])
        ```

        **Por qué ocurre:** Clave inexistente en diccionario.

        **Código corregido**
        ```python
        d = {'a':1}
print(d.get('b', 'no existe'))
        ```

        ---


        # Ejercicio 037 - ValueError: invalid literal for int() (Ejercicio 37)

        **Descripción del error:** No se puede convertir 'dos' a entero.

        **Código con error**
        ```python
        x = 'dos'
n = int(x)
        ```

        **Por qué ocurre:** No se puede convertir 'dos' a entero.

        **Código corregido**
        ```python
        x = '2'
n = int(x)
        ```

        ---


        # Ejercicio 038 - ZeroDivisionError: division by zero (Ejercicio 38)

        **Descripción del error:** División por cero.

        **Código con error**
        ```python
        a = 10
b = 0
print(a/b)
        ```

        **Por qué ocurre:** División por cero.

        **Código corregido**
        ```python
        a = 10
b = 0
if b!=0:
    print(a/b)
else:
    print('división inválida')
        ```

        ---


        # Ejercicio 039 - AttributeError: object has no attribute (Ejercicio 39)

        **Descripción del error:** Tipo incorrecto para método append.

        **Código con error**
        ```python
        n = 5
n.append(3)
        ```

        **Por qué ocurre:** Tipo incorrecto para método append.

        **Código corregido**
        ```python
        lst = [5]
lst.append(3)
        ```

        ---


# Ejercicio 040 - ImportError / ModuleNotFoundError (Ejercicio 40)

**Descripción del error:** Nombre de módulo incorrecto o no instalado.

**Código con error**
```python
import numppy
```

**Por qué ocurre:** Nombre de módulo incorrecto o no instalado.

**Código corregido**
```python
import numpy as np
```

---


        # Ejercicio 041 - SyntaxError: Missing colon (Ejercicio 41)

        **Descripción del error:** Falta ':' al final de la cabecera if/for/def.

        **Código con error**
        ```python
        x = 5
if x > 3
    print('mayor')
        ```

        **Por qué ocurre:** Falta ':' al final de la cabecera if/for/def.

        **Código corregido**
        ```python
        x = 5
if x > 3:
    print('mayor')
        ```

        ---


        # Ejercicio 042 - IndentationError: unexpected indent (Ejercicio 42)

        **Descripción del error:** El cuerpo de la función no está indentado.

        **Código con error**
        ```python
        def f():
print('hola')
        ```

        **Por qué ocurre:** El cuerpo de la función no está indentado.

        **Código corregido**
        ```python
        def f():
    print('hola')
        ```

        ---


        # Ejercicio 043 - NameError: name not defined (Ejercicio 43)

        **Descripción del error:** Se usa una variable no definida.

        **Código con error**
        ```python
        print(resultado)
        ```

        **Por qué ocurre:** Se usa una variable no definida.

        **Código corregido**
        ```python
        resultado = 10
print(resultado)
        ```

        ---


        # Ejercicio 044 - TypeError: unsupported operand type(s) (Ejercicio 44)

        **Descripción del error:** No se pueden sumar str y int sin conversión.

        **Código con error**
        ```python
        a = '5'
b = 3
print(a + b)
        ```

        **Por qué ocurre:** No se pueden sumar str y int sin conversión.

        **Código corregido**
        ```python
        a = '5'
b = 3
print(int(a) + b)
        ```

        ---


        # Ejercicio 045 - IndexError: list index out of range (Ejercicio 45)

        **Descripción del error:** Acceso a índice fuera de rango.

        **Código con error**
        ```python
        lst = [1,2,3]
print(lst[3])
        ```

        **Por qué ocurre:** Acceso a índice fuera de rango.

        **Código corregido**
        ```python
        lst = [1,2,3]
print(lst[2])
        ```

        ---


        # Ejercicio 046 - KeyError: key not found (Ejercicio 46)

        **Descripción del error:** Clave inexistente en diccionario.

        **Código con error**
        ```python
        d = {'a':1}
print(d['b'])
        ```

        **Por qué ocurre:** Clave inexistente en diccionario.

        **Código corregido**
        ```python
        d = {'a':1}
print(d.get('b', 'no existe'))
        ```

        ---


        # Ejercicio 047 - ValueError: invalid literal for int() (Ejercicio 47)

        **Descripción del error:** No se puede convertir 'dos' a entero.

        **Código con error**
        ```python
        x = 'dos'
n = int(x)
        ```

        **Por qué ocurre:** No se puede convertir 'dos' a entero.

        **Código corregido**
        ```python
        x = '2'
n = int(x)
        ```

        ---


        # Ejercicio 048 - ZeroDivisionError: division by zero (Ejercicio 48)

        **Descripción del error:** División por cero.

        **Código con error**
        ```python
        a = 10
b = 0
print(a/b)
        ```

        **Por qué ocurre:** División por cero.

        **Código corregido**
        ```python
        a = 10
b = 0
if b!=0:
    print(a/b)
else:
    print('división inválida')
        ```

        ---


        # Ejercicio 049 - AttributeError: object has no attribute (Ejercicio 49)

        **Descripción del error:** Tipo incorrecto para método append.

        **Código con error**
        ```python
        n = 5
n.append(3)
        ```

        **Por qué ocurre:** Tipo incorrecto para método append.

        **Código corregido**
        ```python
        lst = [5]
lst.append(3)
        ```

        ---


# Ejercicio 050 - ImportError / ModuleNotFoundError (Ejercicio 50)

**Descripción del error:** Nombre de módulo incorrecto o no instalado.

**Código con error**
```python
import numppy
```

**Por qué ocurre:** Nombre de módulo incorrecto o no instalado.

**Código corregido**
```python
import numpy as np
```

---


        # Ejercicio 051 - SyntaxError: Missing colon (Ejercicio 51)

        **Descripción del error:** Falta ':' al final de la cabecera if/for/def.

        **Código con error**
        ```python
        x = 5
if x > 3
    print('mayor')
        ```

        **Por qué ocurre:** Falta ':' al final de la cabecera if/for/def.

        **Código corregido**
        ```python
        x = 5
if x > 3:
    print('mayor')
        ```

        ---


        # Ejercicio 052 - IndentationError: unexpected indent (Ejercicio 52)

        **Descripción del error:** El cuerpo de la función no está indentado.

        **Código con error**
        ```python
        def f():
print('hola')
        ```

        **Por qué ocurre:** El cuerpo de la función no está indentado.

        **Código corregido**
        ```python
        def f():
    print('hola')
        ```

        ---


        # Ejercicio 053 - NameError: name not defined (Ejercicio 53)

        **Descripción del error:** Se usa una variable no definida.

        **Código con error**
        ```python
        print(resultado)
        ```

        **Por qué ocurre:** Se usa una variable no definida.

        **Código corregido**
        ```python
        resultado = 10
print(resultado)
        ```

        ---


        # Ejercicio 054 - TypeError: unsupported operand type(s) (Ejercicio 54)

        **Descripción del error:** No se pueden sumar str y int sin conversión.

        **Código con error**
        ```python
        a = '5'
b = 3
print(a + b)
        ```

        **Por qué ocurre:** No se pueden sumar str y int sin conversión.

        **Código corregido**
        ```python
        a = '5'
b = 3
print(int(a) + b)
        ```

        ---


        # Ejercicio 055 - IndexError: list index out of range (Ejercicio 55)

        **Descripción del error:** Acceso a índice fuera de rango.

        **Código con error**
        ```python
        lst = [1,2,3]
print(lst[3])
        ```

        **Por qué ocurre:** Acceso a índice fuera de rango.

        **Código corregido**
        ```python
        lst = [1,2,3]
print(lst[2])
        ```

        ---


        # Ejercicio 056 - KeyError: key not found (Ejercicio 56)

        **Descripción del error:** Clave inexistente en diccionario.

        **Código con error**
        ```python
        d = {'a':1}
print(d['b'])
        ```

        **Por qué ocurre:** Clave inexistente en diccionario.

        **Código corregido**
        ```python
        d = {'a':1}
print(d.get('b', 'no existe'))
        ```

        ---


        # Ejercicio 057 - ValueError: invalid literal for int() (Ejercicio 57)

        **Descripción del error:** No se puede convertir 'dos' a entero.

        **Código con error**
        ```python
        x = 'dos'
n = int(x)
        ```

        **Por qué ocurre:** No se puede convertir 'dos' a entero.

        **Código corregido**
        ```python
        x = '2'
n = int(x)
        ```

        ---


        # Ejercicio 058 - ZeroDivisionError: division by zero (Ejercicio 58)

        **Descripción del error:** División por cero.

        **Código con error**
        ```python
        a = 10
b = 0
print(a/b)
        ```

        **Por qué ocurre:** División por cero.

        **Código corregido**
        ```python
        a = 10
b = 0
if b!=0:
    print(a/b)
else:
    print('división inválida')
        ```

        ---


        # Ejercicio 059 - AttributeError: object has no attribute (Ejercicio 59)

        **Descripción del error:** Tipo incorrecto para método append.

        **Código con error**
        ```python
        n = 5
n.append(3)
        ```

        **Por qué ocurre:** Tipo incorrecto para método append.

        **Código corregido**
        ```python
        lst = [5]
lst.append(3)
        ```

        ---


# Ejercicio 060 - ImportError / ModuleNotFoundError (Ejercicio 60)

**Descripción del error:** Nombre de módulo incorrecto o no instalado.

**Código con error**
```python
import numppy
```

**Por qué ocurre:** Nombre de módulo incorrecto o no instalado.

**Código corregido**
```python
import numpy as np
```

---


        # Ejercicio 061 - SyntaxError: Missing colon (Ejercicio 61)

        **Descripción del error:** Falta ':' al final de la cabecera if/for/def.

        **Código con error**
        ```python
        x = 5
if x > 3
    print('mayor')
        ```

        **Por qué ocurre:** Falta ':' al final de la cabecera if/for/def.

        **Código corregido**
        ```python
        x = 5
if x > 3:
    print('mayor')
        ```

        ---


        # Ejercicio 062 - IndentationError: unexpected indent (Ejercicio 62)

        **Descripción del error:** El cuerpo de la función no está indentado.

        **Código con error**
        ```python
        def f():
print('hola')
        ```

        **Por qué ocurre:** El cuerpo de la función no está indentado.

        **Código corregido**
        ```python
        def f():
    print('hola')
        ```

        ---


        # Ejercicio 063 - NameError: name not defined (Ejercicio 63)

        **Descripción del error:** Se usa una variable no definida.

        **Código con error**
        ```python
        print(resultado)
        ```

        **Por qué ocurre:** Se usa una variable no definida.

        **Código corregido**
        ```python
        resultado = 10
print(resultado)
        ```

        ---


        # Ejercicio 064 - TypeError: unsupported operand type(s) (Ejercicio 64)

        **Descripción del error:** No se pueden sumar str y int sin conversión.

        **Código con error**
        ```python
        a = '5'
b = 3
print(a + b)
        ```

        **Por qué ocurre:** No se pueden sumar str y int sin conversión.

        **Código corregido**
        ```python
        a = '5'
b = 3
print(int(a) + b)
        ```

        ---


        # Ejercicio 065 - IndexError: list index out of range (Ejercicio 65)

        **Descripción del error:** Acceso a índice fuera de rango.

        **Código con error**
        ```python
        lst = [1,2,3]
print(lst[3])
        ```

        **Por qué ocurre:** Acceso a índice fuera de rango.

        **Código corregido**
        ```python
        lst = [1,2,3]
print(lst[2])
        ```

        ---


        # Ejercicio 066 - KeyError: key not found (Ejercicio 66)

        **Descripción del error:** Clave inexistente en diccionario.

        **Código con error**
        ```python
        d = {'a':1}
print(d['b'])
        ```

        **Por qué ocurre:** Clave inexistente en diccionario.

        **Código corregido**
        ```python
        d = {'a':1}
print(d.get('b', 'no existe'))
        ```

        ---


        # Ejercicio 067 - ValueError: invalid literal for int() (Ejercicio 67)

        **Descripción del error:** No se puede convertir 'dos' a entero.

        **Código con error**
        ```python
        x = 'dos'
n = int(x)
        ```

        **Por qué ocurre:** No se puede convertir 'dos' a entero.

        **Código corregido**
        ```python
        x = '2'
n = int(x)
        ```

        ---


        # Ejercicio 068 - ZeroDivisionError: division by zero (Ejercicio 68)

        **Descripción del error:** División por cero.

        **Código con error**
        ```python
        a = 10
b = 0
print(a/b)
        ```

        **Por qué ocurre:** División por cero.

        **Código corregido**
        ```python
        a = 10
b = 0
if b!=0:
    print(a/b)
else:
    print('división inválida')
        ```

        ---


        # Ejercicio 069 - AttributeError: object has no attribute (Ejercicio 69)

        **Descripción del error:** Tipo incorrecto para método append.

        **Código con error**
        ```python
        n = 5
n.append(3)
        ```

        **Por qué ocurre:** Tipo incorrecto para método append.

        **Código corregido**
        ```python
        lst = [5]
lst.append(3)
        ```

        ---


# Ejercicio 070 - ImportError / ModuleNotFoundError (Ejercicio 70)

**Descripción del error:** Nombre de módulo incorrecto o no instalado.

**Código con error**
```python
import numppy
```

**Por qué ocurre:** Nombre de módulo incorrecto o no instalado.

**Código corregido**
```python
import numpy as np
```

---


        # Ejercicio 071 - SyntaxError: Missing colon (Ejercicio 71)

        **Descripción del error:** Falta ':' al final de la cabecera if/for/def.

        **Código con error**
        ```python
        x = 5
if x > 3
    print('mayor')
        ```

        **Por qué ocurre:** Falta ':' al final de la cabecera if/for/def.

        **Código corregido**
        ```python
        x = 5
if x > 3:
    print('mayor')
        ```

        ---


        # Ejercicio 072 - IndentationError: unexpected indent (Ejercicio 72)

        **Descripción del error:** El cuerpo de la función no está indentado.

        **Código con error**
        ```python
        def f():
print('hola')
        ```

        **Por qué ocurre:** El cuerpo de la función no está indentado.

        **Código corregido**
        ```python
        def f():
    print('hola')
        ```

        ---


        # Ejercicio 073 - NameError: name not defined (Ejercicio 73)

        **Descripción del error:** Se usa una variable no definida.

        **Código con error**
        ```python
        print(resultado)
        ```

        **Por qué ocurre:** Se usa una variable no definida.

        **Código corregido**
        ```python
        resultado = 10
print(resultado)
        ```

        ---


        # Ejercicio 074 - TypeError: unsupported operand type(s) (Ejercicio 74)

        **Descripción del error:** No se pueden sumar str y int sin conversión.

        **Código con error**
        ```python
        a = '5'
b = 3
print(a + b)
        ```

        **Por qué ocurre:** No se pueden sumar str y int sin conversión.

        **Código corregido**
        ```python
        a = '5'
b = 3
print(int(a) + b)
        ```

        ---


        # Ejercicio 075 - IndexError: list index out of range (Ejercicio 75)

        **Descripción del error:** Acceso a índice fuera de rango.

        **Código con error**
        ```python
        lst = [1,2,3]
print(lst[3])
        ```

        **Por qué ocurre:** Acceso a índice fuera de rango.

        **Código corregido**
        ```python
        lst = [1,2,3]
print(lst[2])
        ```

        ---


        # Ejercicio 076 - KeyError: key not found (Ejercicio 76)

        **Descripción del error:** Clave inexistente en diccionario.

        **Código con error**
        ```python
        d = {'a':1}
print(d['b'])
        ```

        **Por qué ocurre:** Clave inexistente en diccionario.

        **Código corregido**
        ```python
        d = {'a':1}
print(d.get('b', 'no existe'))
        ```

        ---


        # Ejercicio 077 - ValueError: invalid literal for int() (Ejercicio 77)

        **Descripción del error:** No se puede convertir 'dos' a entero.

        **Código con error**
        ```python
        x = 'dos'
n = int(x)
        ```

        **Por qué ocurre:** No se puede convertir 'dos' a entero.

        **Código corregido**
        ```python
        x = '2'
n = int(x)
        ```

        ---


        # Ejercicio 078 - ZeroDivisionError: division by zero (Ejercicio 78)

        **Descripción del error:** División por cero.

        **Código con error**
        ```python
        a = 10
b = 0
print(a/b)
        ```

        **Por qué ocurre:** División por cero.

        **Código corregido**
        ```python
        a = 10
b = 0
if b!=0:
    print(a/b)
else:
    print('división inválida')
        ```

        ---


        # Ejercicio 079 - AttributeError: object has no attribute (Ejercicio 79)

        **Descripción del error:** Tipo incorrecto para método append.

        **Código con error**
        ```python
        n = 5
n.append(3)
        ```

        **Por qué ocurre:** Tipo incorrecto para método append.

        **Código corregido**
        ```python
        lst = [5]
lst.append(3)
        ```

        ---


# Ejercicio 080 - ImportError / ModuleNotFoundError (Ejercicio 80)

**Descripción del error:** Nombre de módulo incorrecto o no instalado.

**Código con error**
```python
import numppy
```

**Por qué ocurre:** Nombre de módulo incorrecto o no instalado.

**Código corregido**
```python
import numpy as np
```

---


        # Ejercicio 081 - SyntaxError: Missing colon (Ejercicio 81)

        **Descripción del error:** Falta ':' al final de la cabecera if/for/def.

        **Código con error**
        ```python
        x = 5
if x > 3
    print('mayor')
        ```

        **Por qué ocurre:** Falta ':' al final de la cabecera if/for/def.

        **Código corregido**
        ```python
        x = 5
if x > 3:
    print('mayor')
        ```

        ---


        # Ejercicio 082 - IndentationError: unexpected indent (Ejercicio 82)

        **Descripción del error:** El cuerpo de la función no está indentado.

        **Código con error**
        ```python
        def f():
print('hola')
        ```

        **Por qué ocurre:** El cuerpo de la función no está indentado.

        **Código corregido**
        ```python
        def f():
    print('hola')
        ```

        ---


        # Ejercicio 083 - NameError: name not defined (Ejercicio 83)

        **Descripción del error:** Se usa una variable no definida.

        **Código con error**
        ```python
        print(resultado)
        ```

        **Por qué ocurre:** Se usa una variable no definida.

        **Código corregido**
        ```python
        resultado = 10
print(resultado)
        ```

        ---


        # Ejercicio 084 - TypeError: unsupported operand type(s) (Ejercicio 84)

        **Descripción del error:** No se pueden sumar str y int sin conversión.

        **Código con error**
        ```python
        a = '5'
b = 3
print(a + b)
        ```

        **Por qué ocurre:** No se pueden sumar str y int sin conversión.

        **Código corregido**
        ```python
        a = '5'
b = 3
print(int(a) + b)
        ```

        ---


        # Ejercicio 085 - IndexError: list index out of range (Ejercicio 85)

        **Descripción del error:** Acceso a índice fuera de rango.

        **Código con error**
        ```python
        lst = [1,2,3]
print(lst[3])
        ```

        **Por qué ocurre:** Acceso a índice fuera de rango.

        **Código corregido**
        ```python
        lst = [1,2,3]
print(lst[2])
        ```

        ---


        # Ejercicio 086 - KeyError: key not found (Ejercicio 86)

        **Descripción del error:** Clave inexistente en diccionario.

        **Código con error**
        ```python
        d = {'a':1}
print(d['b'])
        ```

        **Por qué ocurre:** Clave inexistente en diccionario.

        **Código corregido**
        ```python
        d = {'a':1}
print(d.get('b', 'no existe'))
        ```

        ---


        # Ejercicio 087 - ValueError: invalid literal for int() (Ejercicio 87)

        **Descripción del error:** No se puede convertir 'dos' a entero.

        **Código con error**
        ```python
        x = 'dos'
n = int(x)
        ```

        **Por qué ocurre:** No se puede convertir 'dos' a entero.

        **Código corregido**
        ```python
        x = '2'
n = int(x)
        ```

        ---


        # Ejercicio 088 - ZeroDivisionError: division by zero (Ejercicio 88)

        **Descripción del error:** División por cero.

        **Código con error**
        ```python
        a = 10
b = 0
print(a/b)
        ```

        **Por qué ocurre:** División por cero.

        **Código corregido**
        ```python
        a = 10
b = 0
if b!=0:
    print(a/b)
else:
    print('división inválida')
        ```

        ---


        # Ejercicio 089 - AttributeError: object has no attribute (Ejercicio 89)

        **Descripción del error:** Tipo incorrecto para método append.

        **Código con error**
        ```python
        n = 5
n.append(3)
        ```

        **Por qué ocurre:** Tipo incorrecto para método append.

        **Código corregido**
        ```python
        lst = [5]
lst.append(3)
        ```

        ---


# Ejercicio 090 - ImportError / ModuleNotFoundError (Ejercicio 90)

**Descripción del error:** Nombre de módulo incorrecto o no instalado.

**Código con error**
```python
import numppy
```

**Por qué ocurre:** Nombre de módulo incorrecto o no instalado.

**Código corregido**
```python
import numpy as np
```

---


        # Ejercicio 091 - SyntaxError: Missing colon (Ejercicio 91)

        **Descripción del error:** Falta ':' al final de la cabecera if/for/def.

        **Código con error**
        ```python
        x = 5
if x > 3
    print('mayor')
        ```

        **Por qué ocurre:** Falta ':' al final de la cabecera if/for/def.

        **Código corregido**
        ```python
        x = 5
if x > 3:
    print('mayor')
        ```

        ---


        # Ejercicio 092 - IndentationError: unexpected indent (Ejercicio 92)

        **Descripción del error:** El cuerpo de la función no está indentado.

        **Código con error**
        ```python
        def f():
print('hola')
        ```

        **Por qué ocurre:** El cuerpo de la función no está indentado.

        **Código corregido**
        ```python
        def f():
    print('hola')
        ```

        ---


        # Ejercicio 093 - NameError: name not defined (Ejercicio 93)

        **Descripción del error:** Se usa una variable no definida.

        **Código con error**
        ```python
        print(resultado)
        ```

        **Por qué ocurre:** Se usa una variable no definida.

        **Código corregido**
        ```python
        resultado = 10
print(resultado)
        ```

        ---


        # Ejercicio 094 - TypeError: unsupported operand type(s) (Ejercicio 94)

        **Descripción del error:** No se pueden sumar str y int sin conversión.

        **Código con error**
        ```python
        a = '5'
b = 3
print(a + b)
        ```

        **Por qué ocurre:** No se pueden sumar str y int sin conversión.

        **Código corregido**
        ```python
        a = '5'
b = 3
print(int(a) + b)
        ```

        ---


        # Ejercicio 095 - IndexError: list index out of range (Ejercicio 95)

        **Descripción del error:** Acceso a índice fuera de rango.

        **Código con error**
        ```python
        lst = [1,2,3]
print(lst[3])
        ```

        **Por qué ocurre:** Acceso a índice fuera de rango.

        **Código corregido**
        ```python
        lst = [1,2,3]
print(lst[2])
        ```

        ---


        # Ejercicio 096 - KeyError: key not found (Ejercicio 96)

        **Descripción del error:** Clave inexistente en diccionario.

        **Código con error**
        ```python
        d = {'a':1}
print(d['b'])
        ```

        **Por qué ocurre:** Clave inexistente en diccionario.

        **Código corregido**
        ```python
        d = {'a':1}
print(d.get('b', 'no existe'))
        ```

        ---


        # Ejercicio 097 - ValueError: invalid literal for int() (Ejercicio 97)

        **Descripción del error:** No se puede convertir 'dos' a entero.

        **Código con error**
        ```python
        x = 'dos'
n = int(x)
        ```

        **Por qué ocurre:** No se puede convertir 'dos' a entero.

        **Código corregido**
        ```python
        x = '2'
n = int(x)
        ```

        ---


        # Ejercicio 098 - ZeroDivisionError: division by zero (Ejercicio 98)

        **Descripción del error:** División por cero.

        **Código con error**
        ```python
        a = 10
b = 0
print(a/b)
        ```

        **Por qué ocurre:** División por cero.

        **Código corregido**
        ```python
        a = 10
b = 0
if b!=0:
    print(a/b)
else:
    print('división inválida')
        ```

        ---


        # Ejercicio 099 - AttributeError: object has no attribute (Ejercicio 99)

        **Descripción del error:** Tipo incorrecto para método append.

        **Código con error**
        ```python
        n = 5
n.append(3)
        ```

        **Por qué ocurre:** Tipo incorrecto para método append.

        **Código corregido**
        ```python
        lst = [5]
lst.append(3)
        ```

        ---


# Ejercicio 100 - ImportError / ModuleNotFoundError (Ejercicio 100)

**Descripción del error:** Nombre de módulo incorrecto o no instalado.

**Código con error**
```python
import numppy
```

**Por qué ocurre:** Nombre de módulo incorrecto o no instalado.

**Código corregido**
```python
import numpy as np
```

---


        # Ejercicio 101 - SyntaxError: Missing colon (Ejercicio 101)

        **Descripción del error:** Falta ':' al final de la cabecera if/for/def.

        **Código con error**
        ```python
        x = 5
if x > 3
    print('mayor')
        ```

        **Por qué ocurre:** Falta ':' al final de la cabecera if/for/def.

        **Código corregido**
        ```python
        x = 5
if x > 3:
    print('mayor')
        ```

        ---


        # Ejercicio 102 - IndentationError: unexpected indent (Ejercicio 102)

        **Descripción del error:** El cuerpo de la función no está indentado.

        **Código con error**
        ```python
        def f():
print('hola')
        ```

        **Por qué ocurre:** El cuerpo de la función no está indentado.

        **Código corregido**
        ```python
        def f():
    print('hola')
        ```

        ---


        # Ejercicio 103 - NameError: name not defined (Ejercicio 103)

        **Descripción del error:** Se usa una variable no definida.

        **Código con error**
        ```python
        print(resultado)
        ```

        **Por qué ocurre:** Se usa una variable no definida.

        **Código corregido**
        ```python
        resultado = 10
print(resultado)
        ```

        ---


        # Ejercicio 104 - TypeError: unsupported operand type(s) (Ejercicio 104)

        **Descripción del error:** No se pueden sumar str y int sin conversión.

        **Código con error**
        ```python
        a = '5'
b = 3
print(a + b)
        ```

        **Por qué ocurre:** No se pueden sumar str y int sin conversión.

        **Código corregido**
        ```python
        a = '5'
b = 3
print(int(a) + b)
        ```

        ---


        # Ejercicio 105 - IndexError: list index out of range (Ejercicio 105)

        **Descripción del error:** Acceso a índice fuera de rango.

        **Código con error**
        ```python
        lst = [1,2,3]
print(lst[3])
        ```

        **Por qué ocurre:** Acceso a índice fuera de rango.

        **Código corregido**
        ```python
        lst = [1,2,3]
print(lst[2])
        ```

        ---


        # Ejercicio 106 - KeyError: key not found (Ejercicio 106)

        **Descripción del error:** Clave inexistente en diccionario.

        **Código con error**
        ```python
        d = {'a':1}
print(d['b'])
        ```

        **Por qué ocurre:** Clave inexistente en diccionario.

        **Código corregido**
        ```python
        d = {'a':1}
print(d.get('b', 'no existe'))
        ```

        ---


        # Ejercicio 107 - ValueError: invalid literal for int() (Ejercicio 107)

        **Descripción del error:** No se puede convertir 'dos' a entero.

        **Código con error**
        ```python
        x = 'dos'
n = int(x)
        ```

        **Por qué ocurre:** No se puede convertir 'dos' a entero.

        **Código corregido**
        ```python
        x = '2'
n = int(x)
        ```

        ---


        # Ejercicio 108 - ZeroDivisionError: division by zero (Ejercicio 108)

        **Descripción del error:** División por cero.

        **Código con error**
        ```python
        a = 10
b = 0
print(a/b)
        ```

        **Por qué ocurre:** División por cero.

        **Código corregido**
        ```python
        a = 10
b = 0
if b!=0:
    print(a/b)
else:
    print('división inválida')
        ```

        ---


        # Ejercicio 109 - AttributeError: object has no attribute (Ejercicio 109)

        **Descripción del error:** Tipo incorrecto para método append.

        **Código con error**
        ```python
        n = 5
n.append(3)
        ```

        **Por qué ocurre:** Tipo incorrecto para método append.

        **Código corregido**
        ```python
        lst = [5]
lst.append(3)
        ```

        ---


# Ejercicio 110 - ImportError / ModuleNotFoundError (Ejercicio 110)

**Descripción del error:** Nombre de módulo incorrecto o no instalado.

**Código con error**
```python
import numppy
```

**Por qué ocurre:** Nombre de módulo incorrecto o no instalado.

**Código corregido**
```python
import numpy as np
```

---


        # Ejercicio 111 - SyntaxError: Missing colon (Ejercicio 111)

        **Descripción del error:** Falta ':' al final de la cabecera if/for/def.

        **Código con error**
        ```python
        x = 5
if x > 3
    print('mayor')
        ```

        **Por qué ocurre:** Falta ':' al final de la cabecera if/for/def.

        **Código corregido**
        ```python
        x = 5
if x > 3:
    print('mayor')
        ```

        ---


        # Ejercicio 112 - IndentationError: unexpected indent (Ejercicio 112)

        **Descripción del error:** El cuerpo de la función no está indentado.

        **Código con error**
        ```python
        def f():
print('hola')
        ```

        **Por qué ocurre:** El cuerpo de la función no está indentado.

        **Código corregido**
        ```python
        def f():
    print('hola')
        ```

        ---


        # Ejercicio 113 - NameError: name not defined (Ejercicio 113)

        **Descripción del error:** Se usa una variable no definida.

        **Código con error**
        ```python
        print(resultado)
        ```

        **Por qué ocurre:** Se usa una variable no definida.

        **Código corregido**
        ```python
        resultado = 10
print(resultado)
        ```

        ---


        # Ejercicio 114 - TypeError: unsupported operand type(s) (Ejercicio 114)

        **Descripción del error:** No se pueden sumar str y int sin conversión.

        **Código con error**
        ```python
        a = '5'
b = 3
print(a + b)
        ```

        **Por qué ocurre:** No se pueden sumar str y int sin conversión.

        **Código corregido**
        ```python
        a = '5'
b = 3
print(int(a) + b)
        ```

        ---


        # Ejercicio 115 - IndexError: list index out of range (Ejercicio 115)

        **Descripción del error:** Acceso a índice fuera de rango.

        **Código con error**
        ```python
        lst = [1,2,3]
print(lst[3])
        ```

        **Por qué ocurre:** Acceso a índice fuera de rango.

        **Código corregido**
        ```python
        lst = [1,2,3]
print(lst[2])
        ```

        ---


        # Ejercicio 116 - KeyError: key not found (Ejercicio 116)

        **Descripción del error:** Clave inexistente en diccionario.

        **Código con error**
        ```python
        d = {'a':1}
print(d['b'])
        ```

        **Por qué ocurre:** Clave inexistente en diccionario.

        **Código corregido**
        ```python
        d = {'a':1}
print(d.get('b', 'no existe'))
        ```

        ---


        # Ejercicio 117 - ValueError: invalid literal for int() (Ejercicio 117)

        **Descripción del error:** No se puede convertir 'dos' a entero.

        **Código con error**
        ```python
        x = 'dos'
n = int(x)
        ```

        **Por qué ocurre:** No se puede convertir 'dos' a entero.

        **Código corregido**
        ```python
        x = '2'
n = int(x)
        ```

        ---


        # Ejercicio 118 - ZeroDivisionError: division by zero (Ejercicio 118)

        **Descripción del error:** División por cero.

        **Código con error**
        ```python
        a = 10
b = 0
print(a/b)
        ```

        **Por qué ocurre:** División por cero.

        **Código corregido**
        ```python
        a = 10
b = 0
if b!=0:
    print(a/b)
else:
    print('división inválida')
        ```

        ---


        # Ejercicio 119 - AttributeError: object has no attribute (Ejercicio 119)

        **Descripción del error:** Tipo incorrecto para método append.

        **Código con error**
        ```python
        n = 5
n.append(3)
        ```

        **Por qué ocurre:** Tipo incorrecto para método append.

        **Código corregido**
        ```python
        lst = [5]
lst.append(3)
        ```

        ---


# Ejercicio 120 - ImportError / ModuleNotFoundError (Ejercicio 120)

**Descripción del error:** Nombre de módulo incorrecto o no instalado.

**Código con error**
```python
import numppy
```

**Por qué ocurre:** Nombre de módulo incorrecto o no instalado.

**Código corregido**
```python
import numpy as np
```

---


        # Ejercicio 121 - SyntaxError: Missing colon (Ejercicio 121)

        **Descripción del error:** Falta ':' al final de la cabecera if/for/def.

        **Código con error**
        ```python
        x = 5
if x > 3
    print('mayor')
        ```

        **Por qué ocurre:** Falta ':' al final de la cabecera if/for/def.

        **Código corregido**
        ```python
        x = 5
if x > 3:
    print('mayor')
        ```

        ---


        # Ejercicio 122 - IndentationError: unexpected indent (Ejercicio 122)

        **Descripción del error:** El cuerpo de la función no está indentado.

        **Código con error**
        ```python
        def f():
print('hola')
        ```

        **Por qué ocurre:** El cuerpo de la función no está indentado.

        **Código corregido**
        ```python
        def f():
    print('hola')
        ```

        ---


        # Ejercicio 123 - NameError: name not defined (Ejercicio 123)

        **Descripción del error:** Se usa una variable no definida.

        **Código con error**
        ```python
        print(resultado)
        ```

        **Por qué ocurre:** Se usa una variable no definida.

        **Código corregido**
        ```python
        resultado = 10
print(resultado)
        ```

        ---


        # Ejercicio 124 - TypeError: unsupported operand type(s) (Ejercicio 124)

        **Descripción del error:** No se pueden sumar str y int sin conversión.

        **Código con error**
        ```python
        a = '5'
b = 3
print(a + b)
        ```

        **Por qué ocurre:** No se pueden sumar str y int sin conversión.

        **Código corregido**
        ```python
        a = '5'
b = 3
print(int(a) + b)
        ```

        ---


        # Ejercicio 125 - IndexError: list index out of range (Ejercicio 125)

        **Descripción del error:** Acceso a índice fuera de rango.

        **Código con error**
        ```python
        lst = [1,2,3]
print(lst[3])
        ```

        **Por qué ocurre:** Acceso a índice fuera de rango.

        **Código corregido**
        ```python
        lst = [1,2,3]
print(lst[2])
        ```

        ---


        # Ejercicio 126 - KeyError: key not found (Ejercicio 126)

        **Descripción del error:** Clave inexistente en diccionario.

        **Código con error**
        ```python
        d = {'a':1}
print(d['b'])
        ```

        **Por qué ocurre:** Clave inexistente en diccionario.

        **Código corregido**
        ```python
        d = {'a':1}
print(d.get('b', 'no existe'))
        ```

        ---


        # Ejercicio 127 - ValueError: invalid literal for int() (Ejercicio 127)

        **Descripción del error:** No se puede convertir 'dos' a entero.

        **Código con error**
        ```python
        x = 'dos'
n = int(x)
        ```

        **Por qué ocurre:** No se puede convertir 'dos' a entero.

        **Código corregido**
        ```python
        x = '2'
n = int(x)
        ```

        ---


        # Ejercicio 128 - ZeroDivisionError: division by zero (Ejercicio 128)

        **Descripción del error:** División por cero.

        **Código con error**
        ```python
        a = 10
b = 0
print(a/b)
        ```

        **Por qué ocurre:** División por cero.

        **Código corregido**
        ```python
        a = 10
b = 0
if b!=0:
    print(a/b)
else:
    print('división inválida')
        ```

        ---


        # Ejercicio 129 - AttributeError: object has no attribute (Ejercicio 129)

        **Descripción del error:** Tipo incorrecto para método append.

        **Código con error**
        ```python
        n = 5
n.append(3)
        ```

        **Por qué ocurre:** Tipo incorrecto para método append.

        **Código corregido**
        ```python
        lst = [5]
lst.append(3)
        ```

        ---


# Ejercicio 130 - ImportError / ModuleNotFoundError (Ejercicio 130)

**Descripción del error:** Nombre de módulo incorrecto o no instalado.

**Código con error**
```python
import numppy
```

**Por qué ocurre:** Nombre de módulo incorrecto o no instalado.

**Código corregido**
```python
import numpy as np
```

---


        # Ejercicio 131 - SyntaxError: Missing colon (Ejercicio 131)

        **Descripción del error:** Falta ':' al final de la cabecera if/for/def.

        **Código con error**
        ```python
        x = 5
if x > 3
    print('mayor')
        ```

        **Por qué ocurre:** Falta ':' al final de la cabecera if/for/def.

        **Código corregido**
        ```python
        x = 5
if x > 3:
    print('mayor')
        ```

        ---


        # Ejercicio 132 - IndentationError: unexpected indent (Ejercicio 132)

        **Descripción del error:** El cuerpo de la función no está indentado.

        **Código con error**
        ```python
        def f():
print('hola')
        ```

        **Por qué ocurre:** El cuerpo de la función no está indentado.

        **Código corregido**
        ```python
        def f():
    print('hola')
        ```

        ---


        # Ejercicio 133 - NameError: name not defined (Ejercicio 133)

        **Descripción del error:** Se usa una variable no definida.

        **Código con error**
        ```python
        print(resultado)
        ```

        **Por qué ocurre:** Se usa una variable no definida.

        **Código corregido**
        ```python
        resultado = 10
print(resultado)
        ```

        ---


        # Ejercicio 134 - TypeError: unsupported operand type(s) (Ejercicio 134)

        **Descripción del error:** No se pueden sumar str y int sin conversión.

        **Código con error**
        ```python
        a = '5'
b = 3
print(a + b)
        ```

        **Por qué ocurre:** No se pueden sumar str y int sin conversión.

        **Código corregido**
        ```python
        a = '5'
b = 3
print(int(a) + b)
        ```

        ---


        # Ejercicio 135 - IndexError: list index out of range (Ejercicio 135)

        **Descripción del error:** Acceso a índice fuera de rango.

        **Código con error**
        ```python
        lst = [1,2,3]
print(lst[3])
        ```

        **Por qué ocurre:** Acceso a índice fuera de rango.

        **Código corregido**
        ```python
        lst = [1,2,3]
print(lst[2])
        ```

        ---


        # Ejercicio 136 - KeyError: key not found (Ejercicio 136)

        **Descripción del error:** Clave inexistente en diccionario.

        **Código con error**
        ```python
        d = {'a':1}
print(d['b'])
        ```

        **Por qué ocurre:** Clave inexistente en diccionario.

        **Código corregido**
        ```python
        d = {'a':1}
print(d.get('b', 'no existe'))
        ```

        ---


        # Ejercicio 137 - ValueError: invalid literal for int() (Ejercicio 137)

        **Descripción del error:** No se puede convertir 'dos' a entero.

        **Código con error**
        ```python
        x = 'dos'
n = int(x)
        ```

        **Por qué ocurre:** No se puede convertir 'dos' a entero.

        **Código corregido**
        ```python
        x = '2'
n = int(x)
        ```

        ---


        # Ejercicio 138 - ZeroDivisionError: division by zero (Ejercicio 138)

        **Descripción del error:** División por cero.

        **Código con error**
        ```python
        a = 10
b = 0
print(a/b)
        ```

        **Por qué ocurre:** División por cero.

        **Código corregido**
        ```python
        a = 10
b = 0
if b!=0:
    print(a/b)
else:
    print('división inválida')
        ```

        ---


        # Ejercicio 139 - AttributeError: object has no attribute (Ejercicio 139)

        **Descripción del error:** Tipo incorrecto para método append.

        **Código con error**
        ```python
        n = 5
n.append(3)
        ```

        **Por qué ocurre:** Tipo incorrecto para método append.

        **Código corregido**
        ```python
        lst = [5]
lst.append(3)
        ```

        ---


# Ejercicio 140 - ImportError / ModuleNotFoundError (Ejercicio 140)

**Descripción del error:** Nombre de módulo incorrecto o no instalado.

**Código con error**
```python
import numppy
```

**Por qué ocurre:** Nombre de módulo incorrecto o no instalado.

**Código corregido**
```python
import numpy as np
```

---


        # Ejercicio 141 - SyntaxError: Missing colon (Ejercicio 141)

        **Descripción del error:** Falta ':' al final de la cabecera if/for/def.

        **Código con error**
        ```python
        x = 5
if x > 3
    print('mayor')
        ```

        **Por qué ocurre:** Falta ':' al final de la cabecera if/for/def.

        **Código corregido**
        ```python
        x = 5
if x > 3:
    print('mayor')
        ```

        ---


        # Ejercicio 142 - IndentationError: unexpected indent (Ejercicio 142)

        **Descripción del error:** El cuerpo de la función no está indentado.

        **Código con error**
        ```python
        def f():
print('hola')
        ```

        **Por qué ocurre:** El cuerpo de la función no está indentado.

        **Código corregido**
        ```python
        def f():
    print('hola')
        ```

        ---


        # Ejercicio 143 - NameError: name not defined (Ejercicio 143)

        **Descripción del error:** Se usa una variable no definida.

        **Código con error**
        ```python
        print(resultado)
        ```

        **Por qué ocurre:** Se usa una variable no definida.

        **Código corregido**
        ```python
        resultado = 10
print(resultado)
        ```

        ---


        # Ejercicio 144 - TypeError: unsupported operand type(s) (Ejercicio 144)

        **Descripción del error:** No se pueden sumar str y int sin conversión.

        **Código con error**
        ```python
        a = '5'
b = 3
print(a + b)
        ```

        **Por qué ocurre:** No se pueden sumar str y int sin conversión.

        **Código corregido**
        ```python
        a = '5'
b = 3
print(int(a) + b)
        ```

        ---


        # Ejercicio 145 - IndexError: list index out of range (Ejercicio 145)

        **Descripción del error:** Acceso a índice fuera de rango.

        **Código con error**
        ```python
        lst = [1,2,3]
print(lst[3])
        ```

        **Por qué ocurre:** Acceso a índice fuera de rango.

        **Código corregido**
        ```python
        lst = [1,2,3]
print(lst[2])
        ```

        ---


        # Ejercicio 146 - KeyError: key not found (Ejercicio 146)

        **Descripción del error:** Clave inexistente en diccionario.

        **Código con error**
        ```python
        d = {'a':1}
print(d['b'])
        ```

        **Por qué ocurre:** Clave inexistente en diccionario.

        **Código corregido**
        ```python
        d = {'a':1}
print(d.get('b', 'no existe'))
        ```

        ---


        # Ejercicio 147 - ValueError: invalid literal for int() (Ejercicio 147)

        **Descripción del error:** No se puede convertir 'dos' a entero.

        **Código con error**
        ```python
        x = 'dos'
n = int(x)
        ```

        **Por qué ocurre:** No se puede convertir 'dos' a entero.

        **Código corregido**
        ```python
        x = '2'
n = int(x)
        ```

        ---


        # Ejercicio 148 - ZeroDivisionError: division by zero (Ejercicio 148)

        **Descripción del error:** División por cero.

        **Código con error**
        ```python
        a = 10
b = 0
print(a/b)
        ```

        **Por qué ocurre:** División por cero.

        **Código corregido**
        ```python
        a = 10
b = 0
if b!=0:
    print(a/b)
else:
    print('división inválida')
        ```

        ---


        # Ejercicio 149 - AttributeError: object has no attribute (Ejercicio 149)

        **Descripción del error:** Tipo incorrecto para método append.

        **Código con error**
        ```python
        n = 5
n.append(3)
        ```

        **Por qué ocurre:** Tipo incorrecto para método append.

        **Código corregido**
        ```python
        lst = [5]
lst.append(3)
        ```

        ---


# Ejercicio 150 - ImportError / ModuleNotFoundError (Ejercicio 150)

**Descripción del error:** Nombre de módulo incorrecto o no instalado.

**Código con error**
```python
import numppy
```

**Por qué ocurre:** Nombre de módulo incorrecto o no instalado.

**Código corregido**
```python
import numpy as np
```

---
# Out:
#   File "<tokenize>", line 10
#     ```
#     ^
# IndentationError: unindent does not match any outer indentation level
