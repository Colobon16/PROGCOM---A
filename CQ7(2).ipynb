# %% [markdown]
# <a href="https://colab.research.google.com/github/Colobon16/PROGCOM---A/blob/main/CQ7(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
        # Ejercicio 1 - False

        **Definición:** Valor booleano falso.

        **Ejemplo**
        ```python
        x = False
print(x)
        ```

        ---


        # Ejercicio 2 - None

        **Definición:** Representa la ausencia de valor.

        **Ejemplo**
        ```python
        x = None
print(x is None)
        ```

        ---


        # Ejercicio 3 - True

        **Definición:** Valor booleano verdadero.

        **Ejemplo**
        ```python
        x = True
print(x)
        ```

        ---


# Ejercicio 4 - and (Ejercicio 4)

**Definición:** Operador lógico AND.

**Ejemplo**
```python
print(True and False)
```

---


        # Ejercicio 5 - as

        **Definición:** Usado para alias en importación o manejo de contexto.

        **Ejemplo**
        ```python
        import math as m
print(m.sqrt(16))
        ```

        ---


        # Ejercicio 6 - assert

        **Definición:** Verifica una condición, lanza error si es falsa.

        **Ejemplo**
        ```python
        x = 5
assert x > 0
        ```

        ---


    # Ejercicio 7 - break

    **Definición:** Rompe un ciclo.

    **Ejemplo**
    ```python
    for i in range(5):
if i == 3:
    break
print(i)
    ```

    ---


    # Ejercicio 8 - class

    **Definición:** Define una clase.

    **Ejemplo**
    ```python
    class Persona:
pass
    ```

    ---


    # Ejercicio 9 - continue

    **Definición:** Salta a la siguiente iteración en un ciclo.

    **Ejemplo**
    ```python
    for i in range(5):
if i == 2:
    continue
print(i)
    ```

    ---


    # Ejercicio 10 - def

    **Definición:** Define una función.

    **Ejemplo**
    ```python
    def suma(a,b):
return a+b
    ```

    ---


        # Ejercicio 11 - del

        **Definición:** Elimina una variable o elemento.

        **Ejemplo**
        ```python
        x = [1,2,3]
del x[0]
print(x)
        ```

        ---


        # Ejercicio 012 - elif (Ejercicio 12)

        **Definición:** Condición extra en if.

        **Ejemplo**
        ```python
        x=5
if x==1:
    print('uno')
elif x==5:
    print('cinco')
        ```

        ---


        # Ejercicio 013 - else (Ejercicio 13)

        **Definición:** Bloque alternativo en if.

        **Ejemplo**
        ```python
        x=2
if x==1:
    print('uno')
else:
    print('otro')
        ```

        ---


        # Ejercicio 014 - except (Ejercicio 14)

        **Definición:** Manejo de excepciones.

        **Ejemplo**
        ```python
        try:
    1/0
except ZeroDivisionError:
    print('error')
        ```

        ---


        # Ejercicio 015 - finally (Ejercicio 15)

        **Definición:** Bloque que siempre se ejecuta en try-except.

        **Ejemplo**
        ```python
        try:
    x=1/0
except:
    print('error')
finally:
    print('fin')
        ```

        ---


    # Ejercicio 016 - for (Ejercicio 16)

    **Definición:** Bucle for.

    **Ejemplo**
    ```python
    for i in range(3):
print(i)
    ```

    ---


        # Ejercicio 017 - from (Ejercicio 17)

        **Definición:** Importar algo específico de un módulo.

        **Ejemplo**
        ```python
        from math import sqrt
print(sqrt(16))
        ```

        ---


        # Ejercicio 018 - global (Ejercicio 18)

        **Definición:** Acceder/modificar variable global.

        **Ejemplo**
        ```python
        x=5
def f():
    global x
    x=10
f()
print(x)
        ```

        ---


        # Ejercicio 019 - if (Ejercicio 19)

        **Definición:** Estructura condicional.

        **Ejemplo**
        ```python
        x=3
if x>2:
    print('mayor')
        ```

        ---


        # Ejercicio 020 - import (Ejercicio 20)

        **Definición:** Importar módulos.

        **Ejemplo**
        ```python
        import math
print(math.pi)
        ```

        ---


# Ejercicio 021 - in (Ejercicio 21)

**Definición:** Verifica pertenencia.

**Ejemplo**
```python
print(3 in [1,2,3])
```

---


        # Ejercicio 022 - is (Ejercicio 22)

        **Definición:** Comparación de identidad.

        **Ejemplo**
        ```python
        x=None
print(x is None)
        ```

        ---


        # Ejercicio 023 - lambda (Ejercicio 23)

        **Definición:** Define funciones anónimas.

        **Ejemplo**
        ```python
        doble = lambda x: x*2
print(doble(5))
        ```

        ---


        # Ejercicio 024 - nonlocal (Ejercicio 24)

        **Definición:** Permite modificar variables de un scope superior (no global).

        **Ejemplo**
        ```python
        def f():
    x=5
    def g():
        nonlocal x
        x=10
    g()
    print(x)
f()
        ```

        ---


# Ejercicio 025 - not (Ejercicio 25)

**Definición:** Operador lógico NOT.

**Ejemplo**
```python
print(not True)
```

---


# Ejercicio 026 - or (Ejercicio 26)

**Definición:** Operador lógico OR.

**Ejemplo**
```python
print(True or False)
```

---


    # Ejercicio 027 - pass (Ejercicio 27)

    **Definición:** Instrucción vacía (no hace nada).

    **Ejemplo**
    ```python
    def f():
pass
    ```

    ---


# Ejercicio 028 - raise (Ejercicio 28)

**Definición:** Lanza una excepción.

**Ejemplo**
```python
raise ValueError('error')
```

---


        # Ejercicio 029 - return (Ejercicio 29)

        **Definición:** Devuelve un valor en una función.

        **Ejemplo**
        ```python
        def f():
    return 5
print(f())
        ```

        ---


        # Ejercicio 030 - try (Ejercicio 30)

        **Definición:** Inicia bloque de manejo de excepciones.

        **Ejemplo**
        ```python
        try:
    1/0
except:
    print('error')
        ```

        ---


        # Ejercicio 031 - while (Ejercicio 31)

        **Definición:** Bucle while.

        **Ejemplo**
        ```python
        i=0
while i<3:
    print(i)
    i+=1
        ```

        ---


    # Ejercicio 032 - with (Ejercicio 32)

    **Definición:** Manejo de contexto.

    **Ejemplo**
    ```python
    with open('archivo.txt','w') as f:
f.write('hola')
    ```

    ---


        # Ejercicio 033 - yield (Ejercicio 33)

        **Definición:** Devuelve un generador desde una función.

        **Ejemplo**
        ```python
        def gen():
    yield 1
y = gen()
print(next(y))
        ```

        ---


        # Ejercicio 034 - False (Ejercicio 34)

        **Definición:** Valor booleano falso.

        **Ejemplo**
        ```python
        x = False
print(x)
        ```

        ---


        # Ejercicio 035 - None (Ejercicio 35)

        **Definición:** Representa la ausencia de valor.

        **Ejemplo**
        ```python
        x = None
print(x is None)
        ```

        ---


        # Ejercicio 036 - True (Ejercicio 36)

        **Definición:** Valor booleano verdadero.

        **Ejemplo**
        ```python
        x = True
print(x)
        ```

        ---


# Ejercicio 037 - and (Ejercicio 37)

**Definición:** Operador lógico AND.

**Ejemplo**
```python
print(True and False)
```

---


        # Ejercicio 038 - as (Ejercicio 38)

        **Definición:** Usado para alias en importación o manejo de contexto.

        **Ejemplo**
        ```python
        import math as m
print(m.sqrt(16))
        ```

        ---


        # Ejercicio 039 - assert (Ejercicio 39)

        **Definición:** Verifica una condición, lanza error si es falsa.

        **Ejemplo**
        ```python
        x = 5
assert x > 0
        ```

        ---


    # Ejercicio 040 - break (Ejercicio 40)

    **Definición:** Rompe un ciclo.

    **Ejemplo**
    ```python
    for i in range(5):
if i == 3:
    break
print(i)
    ```

    ---


    # Ejercicio 041 - class (Ejercicio 41)

    **Definición:** Define una clase.

    **Ejemplo**
    ```python
    class Persona:
pass
    ```

    ---


    # Ejercicio 042 - continue (Ejercicio 42)

    **Definición:** Salta a la siguiente iteración en un ciclo.

    **Ejemplo**
    ```python
    for i in range(5):
if i == 2:
    continue
print(i)
    ```

    ---


    # Ejercicio 043 - def (Ejercicio 43)

    **Definición:** Define una función.

    **Ejemplo**
    ```python
    def suma(a,b):
return a+b
    ```

    ---


        # Ejercicio 044 - del (Ejercicio 44)

        **Definición:** Elimina una variable o elemento.

        **Ejemplo**
        ```python
        x = [1,2,3]
del x[0]
print(x)
        ```

        ---


        # Ejercicio 045 - elif (Ejercicio 45)

        **Definición:** Condición extra en if.

        **Ejemplo**
        ```python
        x=5
if x==1:
    print('uno')
elif x==5:
    print('cinco')
        ```

        ---


        # Ejercicio 046 - else (Ejercicio 46)

        **Definición:** Bloque alternativo en if.

        **Ejemplo**
        ```python
        x=2
if x==1:
    print('uno')
else:
    print('otro')
        ```

        ---


        # Ejercicio 047 - except (Ejercicio 47)

        **Definición:** Manejo de excepciones.

        **Ejemplo**
        ```python
        try:
    1/0
except ZeroDivisionError:
    print('error')
        ```

        ---


        # Ejercicio 048 - finally (Ejercicio 48)

        **Definición:** Bloque que siempre se ejecuta en try-except.

        **Ejemplo**
        ```python
        try:
    x=1/0
except:
    print('error')
finally:
    print('fin')
        ```

        ---


    # Ejercicio 049 - for (Ejercicio 49)

    **Definición:** Bucle for.

    **Ejemplo**
    ```python
    for i in range(3):
print(i)
    ```

    ---


        # Ejercicio 050 - from (Ejercicio 50)

        **Definición:** Importar algo específico de un módulo.

        **Ejemplo**
        ```python
        from math import sqrt
print(sqrt(16))
        ```

        ---


        # Ejercicio 051 - global (Ejercicio 51)

        **Definición:** Acceder/modificar variable global.

        **Ejemplo**
        ```python
        x=5
def f():
    global x
    x=10
f()
print(x)
        ```

        ---


        # Ejercicio 052 - if (Ejercicio 52)

        **Definición:** Estructura condicional.

        **Ejemplo**
        ```python
        x=3
if x>2:
    print('mayor')
        ```

        ---


        # Ejercicio 053 - import (Ejercicio 53)

        **Definición:** Importar módulos.

        **Ejemplo**
        ```python
        import math
print(math.pi)
        ```

        ---


# Ejercicio 054 - in (Ejercicio 54)

**Definición:** Verifica pertenencia.

**Ejemplo**
```python
print(3 in [1,2,3])
```

---


        # Ejercicio 055 - is (Ejercicio 55)

        **Definición:** Comparación de identidad.

        **Ejemplo**
        ```python
        x=None
print(x is None)
        ```

        ---


        # Ejercicio 056 - lambda (Ejercicio 56)

        **Definición:** Define funciones anónimas.

        **Ejemplo**
        ```python
        doble = lambda x: x*2
print(doble(5))
        ```

        ---


        # Ejercicio 057 - nonlocal (Ejercicio 57)

        **Definición:** Permite modificar variables de un scope superior (no global).

        **Ejemplo**
        ```python
        def f():
    x=5
    def g():
        nonlocal x
        x=10
    g()
    print(x)
f()
        ```

        ---


# Ejercicio 058 - not (Ejercicio 58)

**Definición:** Operador lógico NOT.

**Ejemplo**
```python
print(not True)
```

---


# Ejercicio 059 - or (Ejercicio 59)

**Definición:** Operador lógico OR.

**Ejemplo**
```python
print(True or False)
```

---


    # Ejercicio 060 - pass (Ejercicio 60)

    **Definición:** Instrucción vacía (no hace nada).

    **Ejemplo**
    ```python
    def f():
pass
    ```

    ---


# Ejercicio 061 - raise (Ejercicio 61)

**Definición:** Lanza una excepción.

**Ejemplo**
```python
raise ValueError('error')
```

---


        # Ejercicio 062 - return (Ejercicio 62)

        **Definición:** Devuelve un valor en una función.

        **Ejemplo**
        ```python
        def f():
    return 5
print(f())
        ```

        ---


        # Ejercicio 063 - try (Ejercicio 63)

        **Definición:** Inicia bloque de manejo de excepciones.

        **Ejemplo**
        ```python
        try:
    1/0
except:
    print('error')
        ```

        ---


        # Ejercicio 064 - while (Ejercicio 64)

        **Definición:** Bucle while.

        **Ejemplo**
        ```python
        i=0
while i<3:
    print(i)
    i+=1
        ```

        ---


    # Ejercicio 065 - with (Ejercicio 65)

    **Definición:** Manejo de contexto.

    **Ejemplo**
    ```python
    with open('archivo.txt','w') as f:
f.write('hola')
    ```

    ---


        # Ejercicio 066 - yield (Ejercicio 66)

        **Definición:** Devuelve un generador desde una función.

        **Ejemplo**
        ```python
        def gen():
    yield 1
y = gen()
print(next(y))
        ```

        ---


        # Ejercicio 067 - False (Ejercicio 67)

        **Definición:** Valor booleano falso.

        **Ejemplo**
        ```python
        x = False
print(x)
        ```

        ---


        # Ejercicio 068 - None (Ejercicio 68)

        **Definición:** Representa la ausencia de valor.

        **Ejemplo**
        ```python
        x = None
print(x is None)
        ```

        ---


        # Ejercicio 069 - True (Ejercicio 69)

        **Definición:** Valor booleano verdadero.

        **Ejemplo**
        ```python
        x = True
print(x)
        ```

        ---


# Ejercicio 070 - and (Ejercicio 70)

**Definición:** Operador lógico AND.

**Ejemplo**
```python
print(True and False)
```

---


        # Ejercicio 071 - as (Ejercicio 71)

        **Definición:** Usado para alias en importación o manejo de contexto.

        **Ejemplo**
        ```python
        import math as m
print(m.sqrt(16))
        ```

        ---


        # Ejercicio 072 - assert (Ejercicio 72)

        **Definición:** Verifica una condición, lanza error si es falsa.

        **Ejemplo**
        ```python
        x = 5
assert x > 0
        ```

        ---


    # Ejercicio 073 - break (Ejercicio 73)

    **Definición:** Rompe un ciclo.

    **Ejemplo**
    ```python
    for i in range(5):
if i == 3:
    break
print(i)
    ```

    ---


    # Ejercicio 074 - class (Ejercicio 74)

    **Definición:** Define una clase.

    **Ejemplo**
    ```python
    class Persona:
pass
    ```

    ---


    # Ejercicio 075 - continue (Ejercicio 75)

    **Definición:** Salta a la siguiente iteración en un ciclo.

    **Ejemplo**
    ```python
    for i in range(5):
if i == 2:
    continue
print(i)
    ```

    ---


    # Ejercicio 076 - def (Ejercicio 76)

    **Definición:** Define una función.

    **Ejemplo**
    ```python
    def suma(a,b):
return a+b
    ```

    ---


        # Ejercicio 077 - del (Ejercicio 77)

        **Definición:** Elimina una variable o elemento.

        **Ejemplo**
        ```python
        x = [1,2,3]
del x[0]
print(x)
        ```

        ---


        # Ejercicio 078 - elif (Ejercicio 78)

        **Definición:** Condición extra en if.

        **Ejemplo**
        ```python
        x=5
if x==1:
    print('uno')
elif x==5:
    print('cinco')
        ```

        ---


        # Ejercicio 079 - else (Ejercicio 79)

        **Definición:** Bloque alternativo en if.

        **Ejemplo**
        ```python
        x=2
if x==1:
    print('uno')
else:
    print('otro')
        ```

        ---


        # Ejercicio 080 - except (Ejercicio 80)

        **Definición:** Manejo de excepciones.

        **Ejemplo**
        ```python
        try:
    1/0
except ZeroDivisionError:
    print('error')
        ```

        ---


        # Ejercicio 081 - finally (Ejercicio 81)

        **Definición:** Bloque que siempre se ejecuta en try-except.

        **Ejemplo**
        ```python
        try:
    x=1/0
except:
    print('error')
finally:
    print('fin')
        ```

        ---


    # Ejercicio 082 - for (Ejercicio 82)

    **Definición:** Bucle for.

    **Ejemplo**
    ```python
    for i in range(3):
print(i)
    ```

    ---


        # Ejercicio 083 - from (Ejercicio 83)

        **Definición:** Importar algo específico de un módulo.

        **Ejemplo**
        ```python
        from math import sqrt
print(sqrt(16))
        ```

        ---


        # Ejercicio 084 - global (Ejercicio 84)

        **Definición:** Acceder/modificar variable global.

        **Ejemplo**
        ```python
        x=5
def f():
    global x
    x=10
f()
print(x)
        ```

        ---


        # Ejercicio 085 - if (Ejercicio 85)

        **Definición:** Estructura condicional.

        **Ejemplo**
        ```python
        x=3
if x>2:
    print('mayor')
        ```

        ---


        # Ejercicio 086 - import (Ejercicio 86)

        **Definición:** Importar módulos.

        **Ejemplo**
        ```python
        import math
print(math.pi)
        ```

        ---


# Ejercicio 087 - in (Ejercicio 87)

**Definición:** Verifica pertenencia.

**Ejemplo**
```python
print(3 in [1,2,3])
```

---


        # Ejercicio 088 - is (Ejercicio 88)

        **Definición:** Comparación de identidad.

        **Ejemplo**
        ```python
        x=None
print(x is None)
        ```

        ---


        # Ejercicio 089 - lambda (Ejercicio 89)

        **Definición:** Define funciones anónimas.

        **Ejemplo**
        ```python
        doble = lambda x: x*2
print(doble(5))
        ```

        ---


        # Ejercicio 090 - nonlocal (Ejercicio 90)

        **Definición:** Permite modificar variables de un scope superior (no global).

        **Ejemplo**
        ```python
        def f():
    x=5
    def g():
        nonlocal x
        x=10
    g()
    print(x)
f()
        ```

        ---


# Ejercicio 091 - not (Ejercicio 91)

**Definición:** Operador lógico NOT.

**Ejemplo**
```python
print(not True)
```

---


# Ejercicio 092 - or (Ejercicio 92)

**Definición:** Operador lógico OR.

**Ejemplo**
```python
print(True or False)
```

---


    # Ejercicio 093 - pass (Ejercicio 93)

    **Definición:** Instrucción vacía (no hace nada).

    **Ejemplo**
    ```python
    def f():
pass
    ```

    ---


# Ejercicio 094 - raise (Ejercicio 94)

**Definición:** Lanza una excepción.

**Ejemplo**
```python
raise ValueError('error')
```

---


        # Ejercicio 095 - return (Ejercicio 95)

        **Definición:** Devuelve un valor en una función.

        **Ejemplo**
        ```python
        def f():
    return 5
print(f())
        ```

        ---


        # Ejercicio 096 - try (Ejercicio 96)

        **Definición:** Inicia bloque de manejo de excepciones.

        **Ejemplo**
        ```python
        try:
    1/0
except:
    print('error')
        ```

        ---


        # Ejercicio 097 - while (Ejercicio 97)

        **Definición:** Bucle while.

        **Ejemplo**
        ```python
        i=0
while i<3:
    print(i)
    i+=1
        ```

        ---


    # Ejercicio 098 - with (Ejercicio 98)

    **Definición:** Manejo de contexto.

    **Ejemplo**
    ```python
    with open('archivo.txt','w') as f:
f.write('hola')
    ```

    ---


        # Ejercicio 099 - yield (Ejercicio 99)

        **Definición:** Devuelve un generador desde una función.

        **Ejemplo**
        ```python
        def gen():
    yield 1
y = gen()
print(next(y))
        ```

        ---


        # Ejercicio 100 - False (Ejercicio 100)

        **Definición:** Valor booleano falso.

        **Ejemplo**
        ```python
        x = False
print(x)
        ```

        ---


        # Ejercicio 101 - None (Ejercicio 101)

        **Definición:** Representa la ausencia de valor.

        **Ejemplo**
        ```python
        x = None
print(x is None)
        ```

        ---


        # Ejercicio 102 - True (Ejercicio 102)

        **Definición:** Valor booleano verdadero.

        **Ejemplo**
        ```python
        x = True
print(x)
        ```

        ---


# Ejercicio 103 - and (Ejercicio 103)

**Definición:** Operador lógico AND.

**Ejemplo**
```python
print(True and False)
```

---


        # Ejercicio 104 - as (Ejercicio 104)

        **Definición:** Usado para alias en importación o manejo de contexto.

        **Ejemplo**
        ```python
        import math as m
print(m.sqrt(16))
        ```

        ---


        # Ejercicio 105 - assert (Ejercicio 105)

        **Definición:** Verifica una condición, lanza error si es falsa.

        **Ejemplo**
        ```python
        x = 5
assert x > 0
        ```

        ---


    # Ejercicio 106 - break (Ejercicio 106)

    **Definición:** Rompe un ciclo.

    **Ejemplo**
    ```python
    for i in range(5):
if i == 3:
    break
print(i)
    ```

    ---


    # Ejercicio 107 - class (Ejercicio 107)

    **Definición:** Define una clase.

    **Ejemplo**
    ```python
    class Persona:
pass
    ```

    ---


    # Ejercicio 108 - continue (Ejercicio 108)

    **Definición:** Salta a la siguiente iteración en un ciclo.

    **Ejemplo**
    ```python
    for i in range(5):
if i == 2:
    continue
print(i)
    ```

    ---


    # Ejercicio 109 - def (Ejercicio 109)

    **Definición:** Define una función.

    **Ejemplo**
    ```python
    def suma(a,b):
return a+b
    ```

    ---


        # Ejercicio 110 - del (Ejercicio 110)

        **Definición:** Elimina una variable o elemento.

        **Ejemplo**
        ```python
        x = [1,2,3]
del x[0]
print(x)
        ```

        ---


        # Ejercicio 111 - elif (Ejercicio 111)

        **Definición:** Condición extra en if.

        **Ejemplo**
        ```python
        x=5
if x==1:
    print('uno')
elif x==5:
    print('cinco')
        ```

        ---


        # Ejercicio 112 - else (Ejercicio 112)

        **Definición:** Bloque alternativo en if.

        **Ejemplo**
        ```python
        x=2
if x==1:
    print('uno')
else:
    print('otro')
        ```

        ---


        # Ejercicio 113 - except (Ejercicio 113)

        **Definición:** Manejo de excepciones.

        **Ejemplo**
        ```python
        try:
    1/0
except ZeroDivisionError:
    print('error')
        ```

        ---


        # Ejercicio 114 - finally (Ejercicio 114)

        **Definición:** Bloque que siempre se ejecuta en try-except.

        **Ejemplo**
        ```python
        try:
    x=1/0
except:
    print('error')
finally:
    print('fin')
        ```

        ---


    # Ejercicio 115 - for

    **Definición:** Bucle for.

    **Ejemplo**
    ```python
    for i in range(3):
print(i)
    ```

    ---


        # Ejercicio 116 - from

        **Definición:** Importar algo específico de un módulo.

        **Ejemplo**
        ```python
        from math import sqrt
print(sqrt(16))
        ```

        ---


        # Ejercicio 117 - global

        **Definición:** Acceder/modificar variable global.

        **Ejemplo**
        ```python
        x=5
def f():
    global x
    x=10
f()
print(x)
        ```

        ---


        # Ejercicio 118 - if

        **Definición:** Estructura condicional.

        **Ejemplo**
        ```python
        x=3
if x>2:
    print('mayor')
        ```

        ---


        # Ejercicio 119 - import

        **Definición:** Importar módulos.

        **Ejemplo**
        ```python
        import math
print(math.pi)
        ```

        ---


# Ejercicio 120 - in

**Definición:** Verifica pertenencia.

**Ejemplo**
```python
print(3 in [1,2,3])
```

---


        # Ejercicio 121 - is

        **Definición:** Comparación de identidad.

        **Ejemplo**
        ```python
        x=None
print(x is None)
        ```

        ---


        # Ejercicio 122 - lambda

        **Definición:** Define funciones anónimas.

        **Ejemplo**
        ```python
        doble = lambda x: x*2
print(doble(5))
        ```

        ---


        # Ejercicio 123 - nonlocal

        **Definición:** Permite modificar variables de un scope superior (no global).

        **Ejemplo**
        ```python
        def f():
    x=5
    def g():
        nonlocal x
        x=10
    g()
    print(x)
f()
        ```

        ---


# Ejercicio 124 - not

**Definición:** Operador lógico NOT.

**Ejemplo**
```python
print(not True)
```

---


# Ejercicio 125 - or

**Definición:** Operador lógico OR.

**Ejemplo**
```python
print(True or False)
```

---


    # Ejercicio 126 - pass

    **Definición:** Instrucción vacía (no hace nada).

    **Ejemplo**
    ```python
    def f():
pass
    ```

    ---


# Ejercicio 127 - raise

**Definición:** Lanza una excepción.

**Ejemplo**
```python
raise ValueError('error')
```

---


        # Ejercicio 128 - return

        **Definición:** Devuelve un valor en una función.

        **Ejemplo**
        ```python
        def f():
    return 5
print(f())
        ```

        ---


        # Ejercicio 129 - try

        **Definición:** Inicia bloque de manejo de excepciones.

        **Ejemplo**
        ```python
        try:
    1/0
except:
    print('error')
        ```

        ---


        # Ejercicio 130 - while

        **Definición:** Bucle while.

        **Ejemplo**
        ```python
        i=0
while i<3:
    print(i)
    i+=1
        ```

        ---
